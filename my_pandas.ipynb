# %%
import pandas as pd

# %%
S = pd.Series([11, 12, 23, 45, 65, 34])
S
# Out:
# 0    11
# 1    12
# 2    23
# 3    45
# 4    65
# 5    34
# dtype: int64

# %%
fruits = ['apples', 'oranges', 'cherries', 'pears']
quantities = [10, 20, 30, 40]

S = pd.Series(quantities, index=fruits)
S
# Out:
# apples      10
# oranges     20
# cherries    30
# pears       40
# dtype: int64

# %%
fruits = ['apples', 'oranges', 'cherries', 'pears']
fruits2 = ['stawberries', 'blueberries', 'blackberries', 'raspberries']

S = pd.Series(quantities, index=fruits)
S2 = pd.Series(quantities, index=fruits2)
print(S)
print(S2)

print(S + S2)
# Out:
# apples      10
# oranges     20
# cherries    30
# pears       40
# dtype: int64
# stawberries     10
# blueberries     20
# blackberries    30
# raspberries     40
# dtype: int64
# apples         NaN
# blackberries   NaN
# blueberries    NaN
# cherries       NaN
# oranges        NaN
# pears          NaN
# raspberries    NaN
# stawberries    NaN
# dtype: float64
